# %% [markdown]
# ## EDA Research Question 1: Estimated Ozone Concentrations vs Latitude/Longitude data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import seaborn as sns

# %%
ozone = pd.read_csv("ozone.csv")
ozone = ozone.sample(n= 100000)

ozone2012 = pd.read_csv("ozone2012.csv")
ozone2012 = ozone2012.sample(n = 100000)

ozone2013 = pd.read_csv("ozone2013.csv")
ozone2013 = ozone2013.sample(n = 100000)

ozone2014 = pd.read_csv("ozone2014.csv")
ozone2014 = ozone2014.sample(n = 100000)
ozone2014

ozone_merged = pd.concat([ozone, ozone2012, ozone2013, ozone2014])
ozone_merged = ozone_merged.reset_index(drop=True)
ozone_merged
# Out:
#         year       date  statefips  countyfips        ctfips  latitude  \
# 0       2011  25JUL2011         36     36061.0  3.606102e+10  40.82489
# 1       2011  23JUL2011         36     36059.0  3.605941e+10  40.71049
# 2       2011  25JUL2011         42     42003.0  4.200346e+10  40.50643
# 3       2011  16JUL2011         12     12031.0  1.203102e+10  30.33463
# 4       2011  16JUL2011          4      4012.0  4.012980e+09  33.28276
# ...      ...        ...        ...         ...           ...       ...
# 399995  2014  11JAN2014         48     48029.0  4.802919e+10  29.44810
# 399996  2014  10JAN2014         34     34025.0  3.402581e+10  40.29708
# 399997  2014  05JAN2014         48     48085.0  4.808503e+10  33.15315
# 399998  2014  31JAN2014         26     26129.0  2.612995e+10  44.46414
# 399999  2014  14JAN2014          4      4013.0  4.013108e+09  33.51649
#
#         longitude  ds_o3_pred  ds_o3_stdd
# 0       -73.93610   27.622561    3.603832
# ...

# %%
ax = sns.histplot(data = ozone_merged, x = "ds_o3_pred")
ax.set(title = "histogram of estimated ozone concentrations", xlabel = "ozone concentrations")
plt.show()

# %%
from matplotlib.pyplot import figure

fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(12, 5)
sns.scatterplot(data=ozone, x= "latitude", y="ds_o3_pred", ax=ax1)
ax1.set(ylabel='Estimated Ozone Concentration')
sns.scatterplot(data=ozone, x= "longitude", y="ds_o3_pred", ax=ax2)
fig.suptitle("ozone 2011 vs geographical data")
fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(12, 5)
sns.scatterplot(data=ozone2012, x= "latitude", y="ds_o3_pred", ax=ax1)
ax1.set(ylabel='Estimated Ozone Concentration')
sns.scatterplot(data=ozone2012, x= "longitude", y="ds_o3_pred", ax=ax2)
fig.suptitle("ozone 2012 vs geographical data")
fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(12, 5)
sns.scatterplot(data=ozone2013, x= "latitude", y="ds_o3_pred", ax=ax1)
ax1.set(ylabel='Estimated Ozone Concentration')
sns.scatterplot(data=ozone2013, x= "longitude", y="ds_o3_pred", ax=ax2)
fig.suptitle("ozone 2013 vs geographical data")
fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(12, 5)
sns.scatterplot(data=ozone2014, x= "latitude", y="ds_o3_pred", ax=ax1)
ax1.set(ylabel='Estimated Ozone Concentration')
sns.scatterplot(data=ozone2014, x= "longitude", y="ds_o3_pred", ax=ax2)
fig.suptitle("ozone 2014 vs geographical data")
fig.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
fig.set_size_inches(12, 5)
sns.scatterplot(data=ozone_merged, x= "latitude", y="ds_o3_pred", ax=ax1)
ax1.set(ylabel='Estimated Ozone Concentration')
sns.scatterplot(data=ozone_merged, x= "longitude", y="ds_o3_pred", ax=ax2)
fig.suptitle("ozone vs geographical data")
fig.show()
